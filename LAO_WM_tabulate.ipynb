# %% [markdown]
# # Alive & Thrive
# ## Laos Data: Women Files - Tabulation
# ## Prepared by Aaron Wise; aaron@a3di.dev
# ### Version: 30 September 2022

# %%
from pathlib import Path

import numpy as np
import pandas as pd

pd.set_option("display.max_rows", 1500)
pd.set_option("display.max_columns", None)

import statsmodels.api as sm

# %%
# %load tabulate_imports.py
from tabulate_vars import (
    read_csv_file,
    concatenate_dfs,
    save_combined,
    create_bivariate_var_dep,
    extract_regression_params
)

from aw_analytics import mean_wt, output_mean_table

# %% [markdown]
# ### Create and save combined women's file

# %%
# Set parameters
country = 'LAO'
recode = 'women'

# -------------------------------------------------------------------
year_list = ['2000', '2006', '2012', '2017'] 
# -------------------------------------------------------------------


# Read in files, store dfs in list
list_of_dfs = [read_csv_file(country, recode, year, file_type='working') for year in year_list]

# Combine the dfs
df = concatenate_dfs(list_of_dfs)

# Save and export
save_combined(df, country, recode)
# Out:
# The file -- LAO_women_2000_working.csv -- has the following shape: Rows: 1190; Columns: 16
# The file -- LAO_women_2006_working.csv -- has the following shape: Rows: 1622; Columns: 17
# The file -- LAO_women_2012_working.csv -- has the following shape: Rows: 4444; Columns: 24
# The file -- LAO_women_2017_working.csv -- has the following shape: Rows: 4460; Columns: 23

# %% [markdown]
# ### Run Descriptive stats

# %%
## TOTAL DATASET

# Set parameters
vars = ['anc_4_visits', 'anc_3_components', 'inst_delivery', 'caesarean_del', 'pnc_mother', 'low_bw', 'early_bf', 'iron_supp'] 

ind_vars = ['Total', 'residence', 'region', 'mother_edu', 'wealth_q', 'eth_hoh', 'elderly_hoh', 'sex_hoh']

wt = 'wmweight'

# Run for loop

for year in year_list:

    df = read_csv_file(country, recode, year, file_type='working')

    out_fn = country + "_" + recode + "_" + year + ".xlsx"
    path = Path.cwd() / 'output' / 'frequencies' / recode / out_fn
    
    # Instantiate object
    xlwriter = pd.ExcelWriter(path)
    
    for var in vars:

        try:
            output = output_mean_table(df.dropna(subset=[var]), var, ind_vars, wt)
            sheet_name = str(var) + '_weighted'
            output.to_excel(xlwriter, sheet_name=sheet_name)
        
        except:
            print(f"Warning: Unable to create sheet for var {var}")

    xlwriter.close()
# Out:
# The file -- LAO_women_2000_working.csv -- has the following shape: Rows: 1190; Columns: 16
# Warning: Unable to create sheet for var anc_4_visits
# Warning: Unable to create sheet for var anc_3_components
# Warning: Unable to create sheet for var inst_delivery
# Warning: Unable to create sheet for var caesarean_del
# Warning: Unable to create sheet for var pnc_mother
# Warning: Unable to create sheet for var early_bf
# The file -- LAO_women_2006_working.csv -- has the following shape: Rows: 1622; Columns: 17
# Warning: Unable to create sheet for var anc_4_visits
# Warning: Unable to create sheet for var caesarean_del
# Warning: Unable to create sheet for var pnc_mother
# Warning: Unable to create sheet for var iron_supp
# The file -- LAO_women_2012_working.csv -- has the following shape: Rows: 4444; Columns: 24
# The file -- LAO_women_2017_working.csv -- has the following shape: Rows: 4460; Columns: 23
# Warning: Unable to create sheet for var iron_supp

# %% [markdown]
# ### Run Bivariate stats

# %%
# Read in combined file
df = read_csv_file(country, recode, file_type='combined')

# Create updated bivariate variables (mother_edu_biv, eth_hoh_biv)
df = create_bivariate_var_dep(df, country)
# Out:
# The file -- LAO_women_combined.csv -- has the following shape: Rows: 11716; Columns: 25

# %%
# Set parameters
recode = 'women'
var_dep_list = ['anc_4_visits', 'anc_3_components', 'inst_delivery', 'caesarean_del', 'pnc_mother', 'low_bw', 'early_bf', 'iron_supp'] 

ind_var_list = ['residence', 'region', 'mother_edu_biv', 'wealth_q', 'eth_hoh_biv', 'elderly_hoh', 'sex_hoh']

# Run bivariate (extract WLS regression params)
output = {var_dep: pd.DataFrame({ind_var: extract_regression_params(df, var_dep, ind_var, recode) for ind_var in ind_var_list}) for var_dep in var_dep_list}
# Out:
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.157
# Model:                            WLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     552.4
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:23   Log-Likelihood:                -47359.
# No. Observations:                8904   AIC:                         9.473e+04
# Df Residuals:                    8900   BIC:                         9.475e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          27.2213      0.777     35.037      0.000      25.698      28.744
# int_2017_Urban    -17.1130      2.265     -7.555      0.000     -21.553     -12.673
# Year_2017          27.8410      1.122     24.809      0.000      25.641      30.041
# residence_Urban    43.4023      1.648     26.340      0.000      40.172      46.632
# ==============================================================================
# Omnibus:                      926.699   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              278.507
# Skew:                           0.107   Prob(JB):                     3.33e-61
# Kurtosis:                       2.160   Cond. No.                         6.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.071
# Model:                            WLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     141.7
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.90e-88
# Time:                        12:11:24   Log-Likelihood:                -29894.
# No. Observations:                5544   AIC:                         5.980e+04
# Df Residuals:                    5540   BIC:                         5.982e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           28.3478      1.605     17.659      0.000      25.201      31.495
# int_2017_Central    -2.9310      2.782     -1.053      0.292      -8.385       2.523
# Year_2017           23.4852      2.299     10.213      0.000      18.977      27.993
# region_Central      18.1816      1.948      9.333      0.000      14.363      22.001
# ==============================================================================
# Omnibus:                    27473.313   Durbin-Watson:                   1.405
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              400.486
# Skew:                          -0.049   Prob(JB):                     1.09e-87
# Kurtosis:                       1.687   Cond. No.                         8.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.197
# Model:                            WLS   Adj. R-squared:                  0.197
# Method:                 Least Squares   F-statistic:                     728.3
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:24   Log-Likelihood:                -47142.
# No. Observations:                8904   AIC:                         9.429e+04
# Df Residuals:                    8900   BIC:                         9.432e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      67.8428      1.219     55.636      0.000      65.452      70.233
# int_2017_None_Primary          12.3688      1.994      6.204      0.000       8.461      16.277
# Year_2017                      12.3020      1.589      7.740      0.000       9.186      15.418
# mother_edu_biv_None_Primary   -44.2888      1.458    -30.373      0.000     -47.147     -41.430
# ==============================================================================
# Omnibus:                      196.526   Durbin-Watson:                   1.557
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              113.596
# Skew:                           0.107   Prob(JB):                     2.15e-25
# Kurtosis:                       2.490   Cond. No.                         8.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.455
# Model:                            WLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                     1059.
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:24   Log-Likelihood:                -19387.
# No. Observations:                3801   AIC:                         3.878e+04
# Df Residuals:                    3797   BIC:                         3.881e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            9.0751      1.053      8.620      0.000       7.011      11.139
# int_2017_Richest   -15.4781      2.454     -6.307      0.000     -20.290     -10.666
# Year_2017           23.1691      1.522     15.227      0.000      20.186      26.152
# wealth_q_Richest    73.4996      1.737     42.320      0.000      70.095      76.905
# ==============================================================================
# Omnibus:                      215.089   Durbin-Watson:                   1.720
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              780.120
# Skew:                           0.163   Prob(JB):                    3.97e-170
# Kurtosis:                       5.195   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.196
# Model:                            WLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     723.8
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:24   Log-Likelihood:                -47147.
# No. Observations:                8904   AIC:                         9.430e+04
# Df Residuals:                    8900   BIC:                         9.433e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              14.0419      1.006     13.958      0.000      12.070      16.014
# int_2017_Lao_Tai       -9.4155      1.914     -4.920      0.000     -13.167      -5.664
# Year_2017              30.5372      1.430     21.354      0.000      27.734      33.340
# eth_hoh_biv_Lao_Tai    40.9348      1.347     30.387      0.000      38.294      43.575
# ==============================================================================
# Omnibus:                      452.023   Durbin-Watson:                   1.518
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              214.861
# Skew:                          -0.181   Prob(JB):                     2.21e-47
# Kurtosis:                       2.331   Cond. No.                         7.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.069
# Model:                            WLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     218.8
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          5.81e-137
# Time:                        12:11:24   Log-Likelihood:                -47802.
# No. Observations:                8904   AIC:                         9.561e+04
# Df Residuals:                    8900   BIC:                         9.564e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      42.7698      1.814     23.583      0.000      39.215      46.325
# int_2017_Elderly HoH: NO       -3.8941      2.787     -1.397      0.162      -9.358       1.570
# Year_2017                      28.5487      2.554     11.178      0.000      23.542      33.555
# elderly_hoh_Elderly HoH: NO    -7.0036      1.976     -3.544      0.000     -10.877      -3.130
# ==============================================================================
# Omnibus:                    43340.387   Durbin-Watson:                   1.333
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              658.581
# Skew:                           0.120   Prob(JB):                    9.79e-144
# Kurtosis:                       1.690   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           anc_4_visits   R-squared:                       0.070
# Model:                            WLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     222.8
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          2.29e-139
# Time:                        12:11:24   Log-Likelihood:                -47797.
# No. Observations:                8904   AIC:                         9.560e+04
# Df Residuals:                    8900   BIC:                         9.563e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        51.6044      2.434     21.200      0.000      46.833      56.376
# int_2017_Male     7.0509      3.504      2.012      0.044       0.182      13.920
# Year_2017        18.7676      3.335      5.627      0.000      12.230      25.306
# sex_hoh_Male    -16.1453      2.548     -6.336      0.000     -21.140     -11.151
# ==============================================================================
# Omnibus:                    41863.838   Durbin-Watson:                   1.340
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              653.220
# Skew:                           0.107   Prob(JB):                    1.43e-142
# Kurtosis:                       1.691   Cond. No.                         16.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.131
# Model:                            WLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     304.7
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          2.59e-184
# Time:                        12:11:24   Log-Likelihood:                -31357.
# No. Observations:                6082   AIC:                         6.272e+04
# Df Residuals:                    6078   BIC:                         6.275e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           1.9456      1.069      1.820      0.069      -0.150       4.042
# int_2017_Urban     -0.3410      2.959     -0.115      0.908      -6.142       5.460
# Year_2017          19.9910      1.272     15.713      0.000      17.497      22.485
# residence_Urban    27.1102      2.647     10.243      0.000      21.922      32.298
# ==============================================================================
# Omnibus:                     1311.574   Durbin-Watson:                   1.381
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2357.442
# Skew:                           1.390   Prob(JB):                         0.00
# Kurtosis:                       4.255   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.067
# Model:                            WLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     105.9
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           3.46e-66
# Time:                        12:11:24   Log-Likelihood:                -22979.
# No. Observations:                4415   AIC:                         4.597e+04
# Df Residuals:                    4411   BIC:                         4.599e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            1.7336      1.807      0.959      0.337      -1.810       5.277
# int_2017_Central    -1.6254      2.878     -0.565      0.572      -7.268       4.018
# Year_2017           23.3039      2.134     10.921      0.000      19.121      27.487
# region_Central      11.0603      2.469      4.479      0.000       6.220      15.901
# ==============================================================================
# Omnibus:                      781.487   Durbin-Watson:                   1.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1268.544
# Skew:                           1.302   Prob(JB):                    3.46e-276
# Kurtosis:                       3.332   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.118
# Model:                            WLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     271.7
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          1.79e-165
# Time:                        12:11:24   Log-Likelihood:                -31401.
# No. Observations:                6082   AIC:                         6.281e+04
# Df Residuals:                    6078   BIC:                         6.284e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                           2.6690      1.092      2.444      0.015       0.529       4.809
# int_2017_Secondary_Higher           2.7394      2.799      0.979      0.328      -2.748       8.227
# Year_2017                          16.6266      1.348     12.334      0.000      13.984      19.269
# mother_edu_biv_Secondary_Higher    19.8926      2.531      7.858      0.000      14.930      24.855
# ==============================================================================
# Omnibus:                     1285.125   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2267.104
# Skew:                           1.386   Prob(JB):                         0.00
# Kurtosis:                       4.125   Cond. No.                         10.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.346
# Model:                            WLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     451.0
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          3.08e-235
# Time:                        12:11:24   Log-Likelihood:                -12933.
# No. Observations:                2566   AIC:                         2.587e+04
# Df Residuals:                    2562   BIC:                         2.590e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            0.5549      1.568      0.354      0.723      -2.519       3.629
# int_2017_Richest    16.9986      3.373      5.040      0.000      10.385      23.613
# Year_2017            8.3447      1.887      4.423      0.000       4.645      12.044
# wealth_q_Richest    36.5148      2.938     12.430      0.000      30.754      42.275
# ==============================================================================
# Omnibus:                      190.305   Durbin-Watson:                   1.524
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              319.036
# Skew:                           0.554   Prob(JB):                     5.28e-70
# Kurtosis:                       4.325   Cond. No.                         9.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.135
# Model:                            WLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     474.2
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          4.06e-192
# Time:                        12:11:24   Log-Likelihood:                -31343.
# No. Observations:                6082   AIC:                         6.269e+04
# Df Residuals:                    6079   BIC:                         6.271e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# intercept                  20.4420      0.664     30.785      0.000      19.140      21.744
# int_2017_Non-Lao_Tai      -13.5651      0.912    -14.874      0.000     -15.353     -11.777
# Year_2017                  20.9491      0.664     31.549      0.000      19.647      22.251
# eth_hoh_biv_Non-Lao_Tai   -14.0722      0.664    -21.192      0.000     -15.374     -12.770
# ==============================================================================
# Omnibus:                     1067.721   Durbin-Watson:                   1.406
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1716.590
# Skew:                           1.226   Prob(JB):                         0.00
# Kurtosis:                       3.874   Cond. No.                     1.42e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.06e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.061
# Model:                            WLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     130.6
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           5.72e-82
# Time:                        12:11:25   Log-Likelihood:                -31594.
# No. Observations:                6082   AIC:                         6.320e+04
# Df Residuals:                    6078   BIC:                         6.322e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                       7.9371      2.910      2.728      0.006       2.233      13.641
# int_2017_Elderly HoH: NO       -5.8216      3.519     -1.654      0.098     -12.720       1.077
# Year_2017                      27.6322      3.280      8.424      0.000      21.202      34.063
# elderly_hoh_Elderly HoH: NO    -1.7853      3.105     -0.575      0.565      -7.873       4.302
# ==============================================================================
# Omnibus:                     1447.148   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2707.575
# Skew:                           1.533   Prob(JB):                         0.00
# Kurtosis:                       4.135   Cond. No.                         19.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:       anc_3_components   R-squared:                       0.067
# Model:                            WLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     144.6
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.55e-90
# Time:                        12:11:25   Log-Likelihood:                -31574.
# No. Observations:                6082   AIC:                         6.316e+04
# Df Residuals:                    6078   BIC:                         6.318e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        18.6182      4.015      4.638      0.000      10.748      26.488
# int_2017_Male    -1.3928      4.615     -0.302      0.763     -10.439       7.654
# Year_2017        23.5932      4.448      5.304      0.000      14.873      32.313
# sex_hoh_Male    -13.0821      4.149     -3.153      0.002     -21.215      -4.949
# ==============================================================================
# Omnibus:                     1425.946   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2646.913
# Skew:                           1.514   Prob(JB):                         0.00
# Kurtosis:                       4.131   Cond. No.                         27.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.277
# Model:                            WLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     774.6
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:25   Log-Likelihood:                -31831.
# No. Observations:                6082   AIC:                         6.367e+04
# Df Residuals:                    6078   BIC:                         6.370e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           8.4456      1.156      7.308      0.000       6.180      10.711
# int_2017_Urban    -21.1116      3.198     -6.601      0.000     -27.382     -14.842
# Year_2017          47.3724      1.375     34.449      0.000      44.677      50.068
# residence_Urban    53.1754      2.861     18.588      0.000      47.567      58.783
# ==============================================================================
# Omnibus:                      259.067   Durbin-Watson:                   1.475
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.599
# Skew:                          -0.189   Prob(JB):                     3.59e-30
# Kurtosis:                       2.373   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.184
# Model:                            WLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     290.1
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          7.64e-170
# Time:                        12:11:25   Log-Likelihood:                -20545.
# No. Observations:                3864   AIC:                         4.110e+04
# Df Residuals:                    3860   BIC:                         4.112e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            9.4147      2.352      4.003      0.000       4.804      14.026
# int_2017_Central     1.9632      3.473      0.565      0.572      -4.846       8.772
# Year_2017           41.9574      2.792     15.029      0.000      36.484      47.431
# region_Central      17.8997      2.961      6.045      0.000      12.094      23.705
# ==============================================================================
# Omnibus:                      252.487   Durbin-Watson:                   1.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              127.751
# Skew:                          -0.273   Prob(JB):                     1.82e-28
# Kurtosis:                       2.296   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.281
# Model:                            WLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     793.3
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:25   Log-Likelihood:                -31810.
# No. Observations:                6082   AIC:                         6.363e+04
# Df Residuals:                    6078   BIC:                         6.366e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                           8.8436      1.168      7.572      0.000       6.554      11.133
# int_2017_Secondary_Higher         -12.5830      2.994     -4.203      0.000     -18.453      -6.713
# Year_2017                          41.7033      1.442     28.923      0.000      38.877      44.530
# mother_edu_biv_Secondary_Higher    44.5058      2.708     16.437      0.000      39.198      49.814
# ==============================================================================
# Omnibus:                       90.848   Durbin-Watson:                   1.548
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.806
# Skew:                          -0.176   Prob(JB):                     6.95e-16
# Kurtosis:                       2.610   Cond. No.                         10.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.471
# Model:                            WLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     760.4
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:25   Log-Likelihood:                -13026.
# No. Observations:                2566   AIC:                         2.606e+04
# Df Residuals:                    2562   BIC:                         2.608e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            2.8251      1.625      1.738      0.082      -0.362       6.012
# int_2017_Richest    -8.6649      3.497     -2.478      0.013     -15.522      -1.808
# Year_2017           31.0332      1.956     15.864      0.000      27.197      34.869
# wealth_q_Richest    69.7998      3.046     22.918      0.000      63.828      75.772
# ==============================================================================
# Omnibus:                       85.983   Durbin-Watson:                   1.631
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.340
# Skew:                           0.316   Prob(JB):                     3.02e-29
# Kurtosis:                       3.910   Cond. No.                         9.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.240
# Model:                            WLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     960.7
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):               0.00
# Time:                        12:11:25   Log-Likelihood:                -31980.
# No. Observations:                6082   AIC:                         6.397e+04
# Df Residuals:                    6079   BIC:                         6.399e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# intercept                  35.4381      0.737     48.060      0.000      33.993      36.884
# int_2017_Non-Lao_Tai      -11.5144      1.013    -11.370      0.000     -13.500      -9.529
# Year_2017                  42.2383      0.737     57.282      0.000      40.793      43.684
# eth_hoh_biv_Non-Lao_Tai   -18.3146      0.737    -24.838      0.000     -19.760     -16.869
# ==============================================================================
# Omnibus:                       51.150   Durbin-Watson:                   1.405
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.802
# Skew:                          -0.174   Prob(JB):                     6.87e-11
# Kurtosis:                       2.748   Cond. No.                     1.42e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.06e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.179
# Model:                            WLS   Adj. R-squared:                  0.179
# Method:                 Least Squares   F-statistic:                     441.4
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          1.83e-259
# Time:                        12:11:25   Log-Likelihood:                -32216.
# No. Observations:                6082   AIC:                         6.444e+04
# Df Residuals:                    6078   BIC:                         6.447e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      21.0827      3.223      6.541      0.000      14.764      27.401
# int_2017_Elderly HoH: NO       -4.1498      3.898     -1.065      0.287     -11.792       3.492
# Year_2017                      50.6864      3.633     13.950      0.000      43.564      57.809
# elderly_hoh_Elderly HoH: NO    -4.5099      3.440     -1.311      0.190     -11.253       2.233
# ==============================================================================
# Omnibus:                      531.962   Durbin-Watson:                   1.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.704
# Skew:                          -0.173   Prob(JB):                     3.88e-42
# Kurtosis:                       2.205   Cond. No.                         19.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          inst_delivery   R-squared:                       0.182
# Model:                            WLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     450.2
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          4.04e-264
# Time:                        12:11:25   Log-Likelihood:                -32205.
# No. Observations:                6082   AIC:                         6.442e+04
# Df Residuals:                    6078   BIC:                         6.444e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        32.6045      4.454      7.321      0.000      23.874      41.335
# int_2017_Male     3.7196      5.119      0.727      0.468      -6.316      13.755
# Year_2017        43.4343      4.934      8.802      0.000      33.761      53.108
# sex_hoh_Male    -16.5347      4.603     -3.592      0.000     -25.557      -7.512
# ==============================================================================
# Omnibus:                      527.154   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.515
# Skew:                          -0.182   Prob(JB):                     1.57e-42
# Kurtosis:                       2.208   Cond. No.                         27.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          caesarean_del   R-squared:                       0.044
# Model:                            WLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     135.8
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           4.81e-86
# Time:                        12:11:26   Log-Likelihood:                -40346.
# No. Observations:                8904   AIC:                         8.070e+04
# Df Residuals:                    8900   BIC:                         8.073e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           1.8676      0.353      5.284      0.000       1.175       2.560
# int_2017_Urban      3.2927      1.030      3.195      0.001       1.273       5.313
# Year_2017           0.9343      0.511      1.830      0.067      -0.066       1.935
# residence_Urban     8.1768      0.750     10.907      0.000       6.707       9.646
# ==============================================================================
# Omnibus:                     8243.360   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           226134.755
# Skew:                           4.685   Prob(JB):                         0.00
# Kurtosis:                      25.841   Cond. No.                         6.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          caesarean_del   R-squared:                       0.008
# Model:                            WLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     18.67
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           4.67e-12
# Time:                        12:11:26   Log-Likelihood:                -30386.
# No. Observations:                6665   AIC:                         6.078e+04
# Df Residuals:                    6661   BIC:                         6.081e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            2.2724      0.589      3.858      0.000       1.118       3.427
# int_2017_Central     1.0276      1.085      0.947      0.344      -1.100       3.155
# Year_2017            1.5510      0.833      1.861      0.063      -0.082       3.184
# region_Central       2.8739      0.766      3.751      0.000       1.372       4.376
# ==============================================================================
# ...
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        38.0404      4.806      7.915      0.000      28.618      47.463
# int_2017_Male     8.6821      5.525      1.571      0.116      -2.149      19.513
# Year_2017         8.0858      5.325      1.518      0.129      -2.354      18.526
# sex_hoh_Male     -8.7783      4.967     -1.767      0.077     -18.516       0.959
# ==============================================================================
# Omnibus:                    35257.502   Durbin-Watson:                   1.597
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              676.661
# Skew:                           0.293   Prob(JB):                    1.16e-147
# Kurtosis:                       1.474   Cond. No.                         27.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.173
# Model:                            WLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     391.2
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          8.13e-231
# Time:                        12:11:29   Log-Likelihood:                -29764.
# No. Observations:                5634   AIC:                         5.954e+04
# Df Residuals:                    5630   BIC:                         5.956e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           7.9436      1.446      5.492      0.000       5.108      10.779
# int_2012_Urban      7.6918      3.574      2.152      0.031       0.685      14.699
# Year_2012          35.0255      1.638     21.388      0.000      31.815      38.236
# residence_Urban    26.8832      3.182      8.450      0.000      20.646      33.120
# ==============================================================================
# Omnibus:                      954.784   Durbin-Watson:                   1.491
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              255.077
# Skew:                           0.232   Prob(JB):                     4.08e-56
# Kurtosis:                       2.067   Cond. No.                         10.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.112
# Model:                            WLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     147.1
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           9.02e-90
# Time:                        12:11:29   Log-Likelihood:                -18728.
# No. Observations:                3506   AIC:                         3.746e+04
# Df Residuals:                    3502   BIC:                         3.749e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            9.4118      2.459      3.828      0.000       4.591      14.232
# int_2012_Central    -0.1392      3.899     -0.036      0.972      -7.783       7.505
# Year_2012           37.0609      2.923     12.678      0.000      31.329      42.792
# region_Central      10.2558      3.394      3.022      0.003       3.602      16.909
# ==============================================================================
# Omnibus:                     6036.817   Durbin-Watson:                   1.483
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              234.725
# Skew:                           0.035   Prob(JB):                     1.07e-51
# Kurtosis:                       1.734   Cond. No.                         11.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.201
# Model:                            WLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     471.5
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          2.72e-273
# Time:                        12:11:29   Log-Likelihood:                -29666.
# No. Observations:                5634   AIC:                         5.934e+04
# Df Residuals:                    5630   BIC:                         5.937e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                           9.4698      1.389      6.820      0.000       6.748      12.192
# int_2012_Secondary_Higher          14.2447      3.679      3.872      0.000       7.033      21.457
# Year_2012                          29.7234      1.601     18.570      0.000      26.586      32.861
# mother_edu_biv_Secondary_Higher    23.8781      3.380      7.064      0.000      17.251      30.505
# ==============================================================================
# Omnibus:                      317.453   Durbin-Watson:                   1.599
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.896
# Skew:                           0.291   Prob(JB):                     5.24e-40
# Kurtosis:                       2.342   Cond. No.                         11.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.401
# Model:                            WLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     542.7
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          7.70e-270
# Time:                        12:11:29   Log-Likelihood:                -12424.
# No. Observations:                2431   AIC:                         2.486e+04
# Df Residuals:                    2427   BIC:                         2.488e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            8.2515      2.109      3.912      0.000       4.115      12.388
# int_2012_Richest    56.1317      3.837     14.628      0.000      48.607      63.656
# Year_2012           14.0772      2.371      5.937      0.000       9.427      18.727
# wealth_q_Richest     7.7646      3.396      2.286      0.022       1.105      14.424
# ==============================================================================
# Omnibus:                      299.216   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              694.995
# Skew:                           0.718   Prob(JB):                    1.21e-151
# Kurtosis:                       5.191   Cond. No.                         9.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.214
# Model:                            WLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     512.4
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          1.99e-294
# Time:                        12:11:29   Log-Likelihood:                -29617.
# No. Observations:                5634   AIC:                         5.924e+04
# Df Residuals:                    5630   BIC:                         5.927e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept               8.3067      1.877      4.426      0.000       4.628      11.986
# int_2012_Lao_Tai       29.0435      2.853     10.181      0.000      23.451      34.636
# Year_2012              20.9127      2.123      9.851      0.000      16.751      25.074
# eth_hoh_biv_Lao_Tai     9.3948      2.524      3.722      0.000       4.446      14.343
# ==============================================================================
# Omnibus:                       65.473   Durbin-Watson:                   1.566
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.445
# Skew:                           0.076   Prob(JB):                     3.68e-10
# Kurtosis:                       2.598   Cond. No.                         11.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.099
# Model:                            WLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     206.3
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          6.15e-127
# Time:                        12:11:29   Log-Likelihood:                -30003.
# No. Observations:                5634   AIC:                         6.001e+04
# Df Residuals:                    5630   BIC:                         6.004e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      17.5241      3.672      4.773      0.000      10.326      24.722
# int_2012_Elderly HoH: NO       -3.7658      4.397     -0.857      0.392     -12.385       4.853
# Year_2012                      40.2187      4.080      9.856      0.000      32.219      48.218
# elderly_hoh_Elderly HoH: NO    -4.6479      3.946     -1.178      0.239     -12.383       3.087
# ==============================================================================
# Omnibus:                    24438.462   Durbin-Watson:                   1.383
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              449.460
# Skew:                           0.224   Prob(JB):                     2.52e-98
# Kurtosis:                       1.691   Cond. No.                         21.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              iron_supp   R-squared:                       0.104
# Model:                            WLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):          2.08e-133
# Time:                        12:11:29   Log-Likelihood:                -29988.
# No. Observations:                5634   AIC:                         5.998e+04
# Df Residuals:                    5630   BIC:                         6.001e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        25.1181      5.163      4.865      0.000      14.997      35.239
# int_2012_Male    -4.2477      5.900     -0.720      0.472     -15.814       7.319
# Year_2012        40.7839      5.687      7.172      0.000      29.636      51.932
# sex_hoh_Male    -12.4590      5.346     -2.330      0.020     -22.940      -1.978
# ==============================================================================
# Omnibus:                    16482.565   Durbin-Watson:                   1.396
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              438.802
# Skew:                           0.222   Prob(JB):                     5.19e-96
# Kurtosis:                       1.707   Cond. No.                         30.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None

# %%
# Generate csv of outputs
for var in var_dep_list:
    fn = var + '.csv'
    output[var].transpose().to_csv(f"./output/bivariate/{recode}/{fn}")

# %% [markdown]
# #### Get bivariate differences

# %%
df = read_csv_file(country, recode, file_type='combined')

df = create_bivariate_var_dep(df, country)

var_dep_list = ['anc_4_visits', 'anc_3_components', 'inst_delivery', 'caesarean_del', 'pnc_mother', 'low_bw', 'early_bf', 'iron_supp'] 

ind_var_list = ['residence', 'region', 'mother_edu_biv', 'wealth_q', 'eth_hoh_biv', 'elderly_hoh', 'sex_hoh']


for var in var_dep_list:

    out_fn = var + "_bivariate_diff" + ".xlsx"
    path = Path.cwd() / 'output' / 'bivariate' / recode / out_fn

    # Instantiate object
    xlwriter = pd.ExcelWriter(path)

    for ind_var in ind_var_list:

        output = df.groupby(['Year', ind_var]).apply(mean_wt, var, wt=wt).unstack().transpose()
        
        sheet_name = str(ind_var) + '_weighted'
        output.to_excel(xlwriter, sheet_name=sheet_name)

    xlwriter.close()
# Out:
# The file -- LAO_women_combined.csv -- has the following shape: Rows: 11716; Columns: 25
