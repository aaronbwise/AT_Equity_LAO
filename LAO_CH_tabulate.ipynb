# %% [markdown]
# # Alive & Thrive
# ## Viet Nam Data: Children Files - Tabulation
# ## Prepared by Aaron Wise; aaron@a3di.dev
# ### Version: 14 July 2022

# %%
from pathlib import Path

import numpy as np
import pandas as pd

pd.set_option("display.max_rows", 1500)
pd.set_option("display.max_columns", None)

import statsmodels.api as sm

# %%
# %load tabulate_imports.py
from tabulate_vars import (
    read_csv_file,
    concatenate_dfs,
    save_combined,
    create_bivariate_var_dep,
    extract_regression_params
)

from aw_analytics import mean_wt, output_mean_table

# %% [markdown]
# ### Create and save combined children's file

# %%
# Set parameters
country = 'VNM'
recode = 'children'

# -------------------------------------------------------------------
year_list = ['2000', '2006', '2011', '2014', '2021'] 
# -------------------------------------------------------------------


# Read in files, store dfs in list
list_of_dfs = [read_csv_file(country, recode, year, file_type='working') for year in year_list]

# Combine the dfs
df = concatenate_dfs(list_of_dfs)

# Save and export
save_combined(df, country, recode)
# Out:
# The file -- VNM_children_2000_working.csv -- has the following shape: Rows: 3105; Columns: 21
# The file -- VNM_children_2006_working.csv -- has the following shape: Rows: 2680; Columns: 21
# The file -- VNM_children_2011_working.csv -- has the following shape: Rows: 3678; Columns: 30
# The file -- VNM_children_2014_working.csv -- has the following shape: Rows: 3316; Columns: 42
# The file -- VNM_children_2021_working.csv -- has the following shape: Rows: 4329; Columns: 42

# %% [markdown]
# ### Run Descriptive stats

# %%
## TOTAL DATASET

# Set parameters
vars = ['excl_bf', 'cont_1223_bf', 'mdd_ch', 'mmf_ch', 'mad_ch'] 

ind_vars = ['Total', 'sex_ch', 'residence', 'region', 'mother_edu', 'wealth_q', 'eth_hoh', 'elderly_hoh', 'sex_hoh']

wt = 'chweight'

# Run for loop

for year in year_list:

    df = read_csv_file(country, recode, year, file_type='working')

    out_fn = country + "_" + recode + "_" + year + ".xlsx"
    path = Path.cwd() / 'output' / 'frequencies' / out_fn
    
    # Instantiate object
    xlwriter = pd.ExcelWriter(path)
    
    for var in vars:

        try:
            # df = df.dropna(subset=[var])
            output = output_mean_table(df.dropna(subset=[var]), var, ind_vars, wt)
            sheet_name = str(var) + '_weighted'
            output.to_excel(xlwriter, sheet_name=sheet_name)
        
        except:
            print(f"Warning: Unable to create sheet for var {var}")

    xlwriter.close()
# Out:
# The file -- VNM_children_2000_working.csv -- has the following shape: Rows: 3105; Columns: 21
# Warning: Unable to create sheet for var mdd_ch
# Warning: Unable to create sheet for var mmf_ch
# Warning: Unable to create sheet for var mad_ch
# The file -- VNM_children_2006_working.csv -- has the following shape: Rows: 2680; Columns: 21
# Warning: Unable to create sheet for var mdd_ch
# Warning: Unable to create sheet for var mmf_ch
# Warning: Unable to create sheet for var mad_ch
# The file -- VNM_children_2011_working.csv -- has the following shape: Rows: 3678; Columns: 30
# Warning: Unable to create sheet for var mdd_ch
# Warning: Unable to create sheet for var mad_ch
# The file -- VNM_children_2014_working.csv -- has the following shape: Rows: 3316; Columns: 42
# The file -- VNM_children_2021_working.csv -- has the following shape: Rows: 4329; Columns: 42

# %% [markdown]
# ### Run Bivariate stats

# %%
# Read in combined file
df = read_csv_file(country, recode, file_type='combined')

# Create updated bivariate variables (mother_edu_biv, eth_hoh_biv)
df = create_bivariate_var_dep(df)
# Out:
# The file -- VNM_children_combined.csv -- has the following shape: Rows: 17108; Columns: 42

# %%
# Set parameters
recode = 'children'

var_dep_list = ['excl_bf', 'cont_1223_bf', 'mdd_ch', 'mmf_ch', 'mad_ch'] 

ind_var_list = ['sex_ch', 'residence', 'region', 'mother_edu_biv', 'wealth_q', 'eth_hoh_biv', 'elderly_hoh', 'sex_hoh']

# Run bivariate (extract WLS regression params)
output = {var_dep: pd.DataFrame({ind_var: extract_regression_params(df, var_dep, ind_var, recode) for ind_var in ind_var_list}) for var_dep in var_dep_list}
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.064
# Model:                            WLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     13.90
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           8.80e-09
# Time:                        05:45:37   Log-Likelihood:                -3385.4
# No. Observations:                 618   AIC:                             6779.
# Df Residuals:                     614   BIC:                             6796.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# intercept                  23.3769      4.312      5.422      0.000      14.909      31.845
# int_2021_CH Sex: Female    12.2393      7.708      1.588      0.113      -2.898      27.376
# Year_2021                  17.5260      5.424      3.231      0.001       6.875      28.177
# sex_ch_CH Sex: Female      -0.7653      5.961     -0.128      0.898     -12.471      10.941
# ==============================================================================
# Omnibus:                       39.097   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.127
# Skew:                           0.570   Prob(JB):                     3.19e-09
# Kurtosis:                       2.530   Cond. No.                         7.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.057
# Model:                            WLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     12.44
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           6.62e-08
# Time:                        05:45:37   Log-Likelihood:                -3387.5
# No. Observations:                 618   AIC:                             6783.
# Df Residuals:                     614   BIC:                             6801.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          16.0287      6.640      2.414      0.016       2.990      29.068
# int_2021_Rural     -8.6683      9.113     -0.951      0.342     -26.564       9.227
# Year_2021          30.0456      7.950      3.780      0.000      14.434      45.657
# residence_Rural     8.7110      7.434      1.172      0.242      -5.889      23.311
# ==============================================================================
# Omnibus:                       44.950   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.283
# Skew:                           0.543   Prob(JB):                     2.95e-09
# Kurtosis:                       2.413   Cond. No.                         11.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.128
# Model:                            WLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     7.308
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           0.000132
# Time:                        05:45:37   Log-Likelihood:                -813.26
# No. Observations:                 154   AIC:                             1635.
# Df Residuals:                     150   BIC:                             1647.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# intercept                  1.28e-14      9.366   1.37e-15      1.000     -18.505      18.505
# int_2021_Red River Delta   -18.4255     16.124     -1.143      0.255     -50.284      13.433
# Year_2021                   34.6536     11.511      3.011      0.003      11.909      57.398
# region_Red River Delta      35.1236     13.491      2.604      0.010       8.467      61.780
# ==============================================================================
# Omnibus:                      144.770   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               14.560
# Skew:                           0.350   Prob(JB):                     0.000689
# Kurtosis:                       1.666   Cond. No.                         9.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.065
# Model:                            WLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     14.28
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           5.28e-09
# Time:                        05:45:37   Log-Likelihood:                -3384.9
# No. Observations:                 618   AIC:                             6778.
# Df Residuals:                     614   BIC:                             6795.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          26.6645      4.565      5.841      0.000      17.700      35.629
# int_2021_Secondary_Higher          27.0830     10.707      2.529      0.012       6.056      48.110
# Year_2021                           0.4628      9.635      0.048      0.962     -18.458      19.384
# mother_edu_biv_Secondary_Higher    -6.4100      6.018     -1.065      0.287     -18.228       5.408
# ==============================================================================
# Omnibus:                       41.957   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.717
# Skew:                           0.484   Prob(JB):                     4.77e-08
# Kurtosis:                       2.390   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.056
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     12.18
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           9.50e-08
# Time:                        05:45:37   Log-Likelihood:                -3387.8
# No. Observations:                 618   AIC:                             6784.
# Df Residuals:                     614   BIC:                             6801.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        23.1041      3.384      6.828      0.000      16.459      29.750
# int_2021_Poor     5.1668      9.264      0.558      0.577     -13.027      23.361
# Year_2021        21.9470      4.381      5.010      0.000      13.343      30.551
# wealth_q_Poor    -0.5808      7.218     -0.080      0.936     -14.755      13.594
# ==============================================================================
# Omnibus:                       46.383   Durbin-Watson:                   1.808
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.268
# Skew:                           0.537   Prob(JB):                     2.97e-09
# Kurtosis:                       2.392   Cond. No.                         7.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.063
# Model:                            WLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     13.69
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           1.18e-08
# Time:                        05:45:37   Log-Likelihood:                -3385.7
# No. Observations:                 618   AIC:                             6779.
# Df Residuals:                     614   BIC:                             6797.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# intercept               19.6647      7.234      2.718      0.007       5.459      33.871
# int_2021_Kinh_Hoa      -17.9001     10.216     -1.752      0.080     -37.963       2.162
# Year_2021               37.9407      9.302      4.079      0.000      19.674      56.207
# eth_hoh_biv_Kinh_Hoa     3.9878      7.938      0.502      0.616     -11.601      19.577
# ==============================================================================
# Omnibus:                       49.660   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.956
# Skew:                           0.666   Prob(JB):                     5.22e-12
# Kurtosis:                       2.508   Cond. No.                         13.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.061
# Model:                            WLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     13.26
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           2.13e-08
# Time:                        05:45:37   Log-Likelihood:                -3386.3
# No. Observations:                 618   AIC:                             6781.
# Df Residuals:                     614   BIC:                             6798.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      32.1759      6.714      4.793      0.000      18.991      45.361
# int_2021_Elderly HoH: NO       18.2715      9.491      1.925      0.055      -0.366      36.910
# Year_2021                       8.6557      8.446      1.025      0.306      -7.930      25.242
# elderly_hoh_Elderly HoH: NO   -11.4594      7.493     -1.529      0.127     -26.175       3.256
# ==============================================================================
# Omnibus:                       42.015   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.757
# Skew:                           0.537   Prob(JB):                     6.33e-09
# Kurtosis:                       2.441   Cond. No.                         12.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.058
# Model:                            WLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     12.69
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           4.66e-08
# Time:                        05:45:37   Log-Likelihood:                -3387.1
# No. Observations:                 618   AIC:                             6782.
# Df Residuals:                     614   BIC:                             6800.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          20.6295      3.429      6.016      0.000      13.895      27.364
# int_2021_Female   -12.0535      9.156     -1.316      0.189     -30.035       5.928
# Year_2021          25.9808      4.398      5.908      0.000      17.344      34.617
# sex_hoh_Female      9.6980      6.970      1.391      0.165      -3.991      23.387
# ==============================================================================
# Omnibus:                       46.968   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.603
# Skew:                           0.527   Prob(JB):                     4.15e-09
# Kurtosis:                       2.377   Cond. No.                         7.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.005
# Model:                            WLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.357
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0702
# Time:                        05:45:37   Log-Likelihood:                -7775.3
# No. Observations:                1405   AIC:                         1.556e+04
# Df Residuals:                    1401   BIC:                         1.558e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# intercept                  51.1298      3.031     16.867      0.000      45.183      57.076
# int_2021_CH Sex: Female    -1.4791      5.483     -0.270      0.787     -12.236       9.277
# Year_2021                  -6.5001      3.805     -1.709      0.088     -13.963       0.963
# sex_ch_CH Sex: Female      -0.0178      4.310     -0.004      0.997      -8.473       8.438
# ==============================================================================
# Omnibus:                     3858.096   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.230
# Skew:                           0.121   Prob(JB):                     3.84e-23
# Kurtosis:                       1.694   Cond. No.                         7.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.008
# Model:                            WLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.699
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0114
# Time:                        05:45:37   Log-Likelihood:                -7773.3
# No. Observations:                1405   AIC:                         1.555e+04
# Df Residuals:                    1401   BIC:                         1.558e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          52.8467      2.406     21.966      0.000      48.127      57.566
# int_2021_Urban      3.9870      6.496      0.614      0.539      -8.755      16.729
# Year_2021          -7.4538      3.151     -2.366      0.018     -13.635      -1.273
# residence_Urban    -8.6312      5.380     -1.604      0.109     -19.186       1.923
# ==============================================================================
# Omnibus:                     2948.875   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.855
# Skew:                           0.120   Prob(JB):                     1.26e-22
# Kurtosis:                       1.710   Cond. No.                         7.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.041
# Model:                            WLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     6.163
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           0.000414
# Time:                        05:45:37   Log-Likelihood:                -2356.9
# No. Observations:                 438   AIC:                             4722.
# Df Residuals:                     434   BIC:                             4738.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# intercept                                   37.8079      5.864      6.448      0.000      26.283      49.333
# int_2021_North Central and Central Coast   -10.0297      9.672     -1.037      0.300     -29.039       8.980
# Year_2021                                   -4.5688      7.455     -0.613      0.540     -19.222      10.084
# region_North Central and Central Coast      22.0711      7.452      2.962      0.003       7.424      36.718
# ==============================================================================
# Omnibus:                     5316.360   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.414
# Skew:                           0.247   Prob(JB):                     3.74e-10
# Kurtosis:                       1.539   Cond. No.                         8.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     4.512
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):            0.00371
# Time:                        05:45:37   Log-Likelihood:                -7772.1
# No. Observations:                1405   AIC:                         1.555e+04
# Df Residuals:                    1401   BIC:                         1.557e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          56.4585      3.370     16.754      0.000      49.848      63.069
# int_2021_Secondary_Higher          16.8173      6.679      2.518      0.012       3.714      29.920
# Year_2021                         -19.3324      5.793     -3.337      0.001     -30.697      -7.968
# mother_edu_biv_Secondary_Higher    -9.0027      4.376     -2.057      0.040     -17.588      -0.418
# ==============================================================================
# Omnibus:                     3702.437   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.859
# Skew:                           0.101   Prob(JB):                     7.61e-23
# Kurtosis:                       1.697   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.007
# Model:                            WLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.459
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0159
# Time:                        05:45:37   Log-Likelihood:                -7773.6
# No. Observations:                1405   AIC:                         1.556e+04
# Df Residuals:                    1401   BIC:                         1.558e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           52.7778      2.332     22.629      0.000      48.203      57.353
# int_2021_Richest    10.0249      7.278      1.377      0.169      -4.252      24.302
# Year_2021           -8.5771      3.020     -2.840      0.005     -14.501      -2.654
# wealth_q_Richest   -11.1744      6.057     -1.845      0.065     -23.056       0.708
# ==============================================================================
# Omnibus:                     2947.655   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.295
# Skew:                           0.128   Prob(JB):                     1.01e-22
# Kurtosis:                       1.710   Cond. No.                         8.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.013
# Model:                            WLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.340
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           0.000287
# Time:                        05:45:37   Log-Likelihood:                -7769.3
# No. Observations:                1405   AIC:                         1.555e+04
# Df Residuals:                    1401   BIC:                         1.557e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# intercept               55.3807      4.879     11.351      0.000      45.810      64.952
# int_2021_Kinh_Hoa      -10.0937      7.123     -1.417      0.157     -24.066       3.878
# Year_2021                1.4984      6.454      0.232      0.816     -11.163      14.160
# eth_hoh_biv_Kinh_Hoa    -5.2814      5.433     -0.972      0.331     -15.939       5.376
# ==============================================================================
# Omnibus:                     1459.969   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.151
# Skew:                           0.229   Prob(JB):                     1.08e-22
# Kurtosis:                       1.768   Cond. No.                         13.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.006
# Model:                            WLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.946
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0319
# Time:                        05:45:37   Log-Likelihood:                -7774.4
# No. Observations:                1405   AIC:                         1.556e+04
# Df Residuals:                    1401   BIC:                         1.558e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      44.7087      5.088      8.787      0.000      34.727      54.690
# int_2021_Elderly HoH: NO       -7.2326      7.056     -1.025      0.306     -21.074       6.608
# Year_2021                      -1.2348      6.372     -0.194      0.846     -13.734      11.264
# elderly_hoh_Elderly HoH: NO     7.8119      5.616      1.391      0.164      -3.205      18.829
# ==============================================================================
# Omnibus:                     3672.654   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.888
# Skew:                           0.122   Prob(JB):                     4.55e-23
# Kurtosis:                       1.697   Cond. No.                         13.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.007
# Model:                            WLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.353
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0184
# Time:                        05:45:37   Log-Likelihood:                -7773.8
# No. Observations:                1405   AIC:                         1.556e+04
# Df Residuals:                    1401   BIC:                         1.558e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        49.4035      4.789     10.316      0.000      40.009      58.798
# int_2021_Male    -9.3064      6.765     -1.376      0.169     -22.577       3.964
# Year_2021         0.1720      6.028      0.029      0.977     -11.654      11.998
# sex_hoh_Male      2.1524      5.361      0.401      0.688      -8.364      12.669
# ==============================================================================
# Omnibus:                     3196.102   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.934
# Skew:                           0.126   Prob(JB):                     7.33e-23
# Kurtosis:                       1.705   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.004
# Model:                            WLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.149
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0241
# Time:                        05:45:37   Log-Likelihood:                -12828.
# No. Observations:                2335   AIC:                         2.566e+04
# Df Residuals:                    2331   BIC:                         2.569e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# intercept                59.7722      2.161     27.664      0.000      55.535      64.009
# int_2021_CH Sex: Male     8.5924      4.107      2.092      0.037       0.539      16.646
# Year_2021                -8.2637      3.003     -2.752      0.006     -14.152      -2.375
# sex_ch_CH Sex: Male      -1.6514      2.962     -0.557      0.577      -7.461       4.158
# ==============================================================================
# Omnibus:                    24756.263   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              198.541
# Skew:                          -0.139   Prob(JB):                     7.71e-44
# Kurtosis:                       1.599   Cond. No.                         7.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.007
# Model:                            WLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.148
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):            0.00151
# Time:                        05:45:37   Log-Likelihood:                -12825.
# No. Observations:                2335   AIC:                         2.566e+04
# Df Residuals:                    2331   BIC:                         2.568e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          58.0182      1.763     32.901      0.000      54.560      61.476
# int_2021_Urban      7.4268      4.447      1.670      0.095      -1.294      16.147
# Year_2021          -5.9880      2.453     -2.441      0.015     -10.798      -1.178
# residence_Urban     2.9269      3.224      0.908      0.364      -3.396       9.250
# ==============================================================================
# Omnibus:                    36544.300   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.737
# Skew:                          -0.129   Prob(JB):                     6.30e-42
# Kurtosis:                       1.627   Cond. No.                         6.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.048
# Model:                            WLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           5.00e-07
# Time:                        05:45:37   Log-Likelihood:                -3600.7
# No. Observations:                 658   AIC:                             7209.
# Df Residuals:                     654   BIC:                             7227.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# intercept                                   45.9706      3.900     11.786      0.000      38.312      53.630
# int_2021_North Central and Central Coast   -12.3818      7.573     -1.635      0.103     -27.252       2.489
# Year_2021                                    6.0579      5.778      1.048      0.295      -5.287      17.403
# region_North Central and Central Coast      26.8017      5.274      5.082      0.000      16.446      37.158
# ==============================================================================
# Omnibus:                      261.603   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.913
# Skew:                          -0.345   Prob(JB):                     6.50e-11
# Kurtosis:                       1.888   Cond. No.                         7.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.039
# Model:                            WLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     31.42
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           6.56e-20
# Time:                        05:45:37   Log-Likelihood:                -12786.
# No. Observations:                2335   AIC:                         2.558e+04
# Df Residuals:                    2331   BIC:                         2.560e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          34.8308      3.529      9.870      0.000      27.911      41.751
# int_2021_Secondary_Higher          -3.3796      5.805     -0.582      0.560     -14.763       8.004
# Year_2021                          -2.1696      5.381     -0.403      0.687     -12.722       8.383
# mother_edu_biv_Secondary_Higher    28.9675      3.872      7.481      0.000      21.375      36.560
# ==============================================================================
# Omnibus:                     1479.450   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.549
# Skew:                          -0.226   Prob(JB):                     7.49e-34
# Kurtosis:                       1.833   Cond. No.                         13.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.014
# Model:                            WLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     11.37
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           2.11e-07
# Time:                        05:45:37   Log-Likelihood:                -12816.
# No. Observations:                2335   AIC:                         2.564e+04
# Df Residuals:                    2331   BIC:                         2.566e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           56.7083      1.643     34.509      0.000      53.486      59.931
# int_2021_Richest     5.1478      5.034      1.023      0.307      -4.723      15.019
# Year_2021           -4.9344      2.288     -2.156      0.031      -9.422      -0.447
# wealth_q_Richest    10.9657      3.681      2.979      0.003       3.747      18.184
# ==============================================================================
# Omnibus:                     8663.218   Durbin-Watson:                   1.815
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              174.772
# Skew:                          -0.140   Prob(JB):                     1.12e-38
# Kurtosis:                       1.689   Cond. No.                         6.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.028
# Model:                            WLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     22.57
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           2.12e-14
# Time:                        05:45:37   Log-Likelihood:                -12799.
# No. Observations:                2335   AIC:                         2.561e+04
# Df Residuals:                    2331   BIC:                         2.563e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# intercept               42.0000      3.667     11.454      0.000      34.809      49.191
# int_2021_Kinh_Hoa        3.5121      5.493      0.639      0.523      -7.259      14.283
# Year_2021               -6.4385      5.028     -1.280      0.201     -16.299       3.422
# eth_hoh_biv_Kinh_Hoa    20.0771      3.997      5.022      0.000      12.238      27.916
# ==============================================================================
# Omnibus:                     1869.757   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              174.998
# Skew:                          -0.304   Prob(JB):                     9.99e-39
# Kurtosis:                       1.804   Cond. No.                         12.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.003
# Model:                            WLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.502
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):             0.0577
# Time:                        05:45:37   Log-Likelihood:                -12829.
# No. Observations:                2335   AIC:                         2.567e+04
# Df Residuals:                    2331   BIC:                         2.569e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      59.4820      3.064     19.410      0.000      53.473      65.491
# int_2021_Elderly HoH: NO       -6.7135      5.032     -1.334      0.182     -16.581       3.154
# Year_2021                       1.8169      4.470      0.406      0.684      -6.949      10.583
# elderly_hoh_Elderly HoH: NO    -0.7668      3.499     -0.219      0.827      -7.628       6.094
# ==============================================================================
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# intercept                56.6043      2.172     26.057      0.000      52.344      60.864
# int_2021_CH Sex: Male     9.7204      4.129      2.354      0.019       1.623      17.818
# Year_2021               -15.2106      3.019     -5.038      0.000     -21.131      -9.290
# sex_ch_CH Sex: Male      -2.5993      2.978     -0.873      0.383      -8.440       3.241
# ==============================================================================
# Omnibus:                    26928.611   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.123
# Skew:                           0.184   Prob(JB):                     2.33e-41
# Kurtosis:                       1.663   Cond. No.                         7.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.013
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     10.17
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           1.18e-06
# Time:                        05:45:37   Log-Likelihood:                -12841.
# No. Observations:                2335   AIC:                         2.569e+04
# Df Residuals:                    2331   BIC:                         2.571e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          54.2329      1.775     30.550      0.000      50.752      57.714
# int_2021_Urban      4.1817      4.477      0.934      0.350      -4.597      12.960
# Year_2021         -11.3320      2.469     -4.589      0.000     -16.174      -6.490
# residence_Urban     3.3054      3.246      1.018      0.309      -3.060       9.670
# ==============================================================================
# Omnibus:                     9874.295   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              182.989
# Skew:                           0.194   Prob(JB):                     1.84e-40
# Kurtosis:                       1.684   Cond. No.                         6.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.051
# Model:                            WLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     11.63
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           1.96e-07
# Time:                        05:45:37   Log-Likelihood:                -3614.6
# No. Observations:                 658   AIC:                             7237.
# Df Residuals:                     654   BIC:                             7255.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# intercept                                   42.8396      3.984     10.753      0.000      35.017      50.662
# int_2021_North Central and Central Coast    -9.5181      7.735     -1.230      0.219     -24.707       5.671
# Year_2021                                   -4.4790      5.901     -0.759      0.448     -16.067       7.109
# region_North Central and Central Coast      25.1629      5.387      4.671      0.000      14.585      35.741
# ==============================================================================
# Omnibus:                      450.540   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.578
# Skew:                           0.005   Prob(JB):                     2.54e-09
# Kurtosis:                       1.799   Cond. No.                         7.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.039
# Model:                            WLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     31.88
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           3.41e-20
# Time:                        05:45:37   Log-Likelihood:                -12809.
# No. Observations:                2335   AIC:                         2.563e+04
# Df Residuals:                    2331   BIC:                         2.565e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          32.6013      3.563      9.150      0.000      25.614      39.588
# int_2021_Secondary_Higher          -6.3332      5.861     -1.081      0.280     -17.826       5.160
# Year_2021                          -5.8194      5.433     -1.071      0.284     -16.474       4.835
# mother_edu_biv_Secondary_Higher    27.2309      3.909      6.966      0.000      19.565      34.897
# ==============================================================================
# Omnibus:                     2052.306   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              146.708
# Skew:                           0.109   Prob(JB):                     1.39e-32
# Kurtosis:                       1.792   Cond. No.                         13.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.022
# Model:                            WLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     17.23
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           4.55e-11
# Time:                        05:45:37   Log-Likelihood:                -12830.
# No. Observations:                2335   AIC:                         2.567e+04
# Df Residuals:                    2331   BIC:                         2.569e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           52.6416      1.653     31.837      0.000      49.399      55.884
# int_2021_Richest     0.7442      5.065      0.147      0.883      -9.188      10.676
# Year_2021          -10.3644      2.302     -4.502      0.000     -14.879      -5.849
# wealth_q_Richest    12.9457      3.704      3.495      0.000       5.683      20.209
# ==============================================================================
# Omnibus:                     3403.543   Durbin-Watson:                   1.815
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              166.596
# Skew:                           0.183   Prob(JB):                     6.67e-37
# Kurtosis:                       1.743   Cond. No.                         6.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.032
# Model:                            WLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     25.44
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           3.42e-16
# Time:                        05:45:37   Log-Likelihood:                -12818.
# No. Observations:                2335   AIC:                         2.564e+04
# Df Residuals:                    2331   BIC:                         2.567e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# intercept               36.8626      3.697      9.972      0.000      29.614      44.112
# int_2021_Kinh_Hoa       -3.6141      5.537     -0.653      0.514     -14.472       7.244
# Year_2021               -6.8271      5.069     -1.347      0.178     -16.767       3.113
# eth_hoh_biv_Kinh_Hoa    21.8185      4.030      5.414      0.000      13.916      29.721
# ==============================================================================
# Omnibus:                     3209.984   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.382
# Skew:                           0.048   Prob(JB):                     4.94e-34
# Kurtosis:                       1.748   Cond. No.                         12.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.013
# Model:                            WLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     10.21
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           1.12e-06
# Time:                        05:45:38   Log-Likelihood:                -12841.
# No. Observations:                2335   AIC:                         2.569e+04
# Df Residuals:                    2331   BIC:                         2.571e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      56.2591      3.080     18.268      0.000      50.220      62.298
# int_2021_Elderly HoH: NO       -8.2005      5.057     -1.622      0.105     -18.117       1.716
# Year_2021                      -3.2995      4.493     -0.734      0.463     -12.109       5.510
# elderly_hoh_Elderly HoH: NO    -1.3524      3.516     -0.385      0.701      -8.248       5.543
# ==============================================================================
# Omnibus:                    12308.276   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              184.297
# Skew:                           0.191   Prob(JB):                     9.56e-41
# Kurtosis:                       1.678   Cond. No.                         10.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mad_ch   R-squared:                       0.010
# Model:                            WLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     8.182
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           2.04e-05
# Time:                        05:45:38   Log-Likelihood:                -12844.
# No. Observations:                2335   AIC:                         2.570e+04
# Df Residuals:                    2331   BIC:                         2.572e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          54.6902      1.691     32.339      0.000      51.374      58.007
# int_2021_Female     0.2670      4.919      0.054      0.957      -9.379       9.913
# Year_2021         -10.0696      2.346     -4.292      0.000     -14.671      -5.469
# sex_hoh_Female      2.3537      3.559      0.661      0.508      -4.626       9.333
# ==============================================================================
# Omnibus:                   106820.240   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.793
# Skew:                           0.184   Prob(JB):                     3.71e-42
# Kurtosis:                       1.649   Cond. No.                         6.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None

# %%
# Generate csv of outputs
for var in var_dep_list:
    fn = var + '.csv'
    output[var].transpose().to_csv(f"./output/bivariate/{recode}/{fn}")

# %% [markdown]
# #### Get bivariate differences

# %%
df = read_csv_file(country, recode, file_type='combined')

df = create_bivariate_var_dep(df)

var_dep_list = ['excl_bf', 'cont_1223_bf', 'mdd_ch', 'mmf_ch', 'mad_ch'] 

ind_var_list = ['sex_ch', 'residence', 'region', 'mother_edu_biv', 'wealth_q', 'eth_hoh_biv', 'elderly_hoh', 'sex_hoh']


for var in var_dep_list:

    out_fn = var + "_bivariate_diff" + ".xlsx"
    path = Path.cwd() / 'output' / 'bivariate' / recode / out_fn

    # Instantiate object
    xlwriter = pd.ExcelWriter(path)

    for ind_var in ind_var_list:

        output = df.groupby(['Year', ind_var]).apply(mean_wt, var, wt=wt)
        
        sheet_name = str(ind_var) + '_weighted'
        output.to_excel(xlwriter, sheet_name=sheet_name)

    xlwriter.close()
# Out:
# The file -- VNM_children_combined.csv -- has the following shape: Rows: 17108; Columns: 42
