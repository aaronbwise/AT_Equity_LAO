# %% [markdown]
# # Alive & Thrive
# ## Viet Nam Data: Children Files - Tabulation
# ## Prepared by Aaron Wise; aaron@a3di.dev
# ### Version: 14 July 2022

# %%
from pathlib import Path

import numpy as np
import pandas as pd

pd.set_option("display.max_rows", 1500)
pd.set_option("display.max_columns", None)

import statsmodels.api as sm

# %%
# %load tabulate_imports.py
from tabulate_vars import (
    read_csv_file,
    concatenate_dfs,
    save_combined,
    create_bivariate_var_dep,
    extract_regression_params
)

from aw_analytics import mean_wt, output_mean_table

# %% [markdown]
# ### Create and save combined children's file

# %%
# Set parameters
country = 'LAO'
recode = 'children'

# -------------------------------------------------------------------
year_list = ['2000', '2006', '2012', '2017'] 
# -------------------------------------------------------------------


# Read in files, store dfs in list
list_of_dfs = [read_csv_file(country, recode, year, file_type='working') for year in year_list]

# Combine the dfs
df = concatenate_dfs(list_of_dfs)

# Save and export
save_combined(df, country, recode)
# Out:
# The file -- LAO_children_2000_working.csv -- has the following shape: Rows: 5152; Columns: 31
# The file -- LAO_children_2006_working.csv -- has the following shape: Rows: 4136; Columns: 25
# The file -- LAO_children_2012_working.csv -- has the following shape: Rows: 11067; Columns: 34
# The file -- LAO_children_2017_working.csv -- has the following shape: Rows: 11720; Columns: 46

# %% [markdown]
# ### Run Descriptive stats

# %%
## TOTAL DATASET

# Set parameters
vars = ['excl_bf', 'cont_1223_bf', 'mdd_ch', 'mmf_ch', 'mad_ch', 'stunting_ch', 'wasting_ch', 'overweight_ch'] 

ind_vars = ['Total', 'sex_ch', 'residence', 'region', 'mother_edu', 'wealth_q', 'eth_hoh', 'elderly_hoh', 'sex_hoh']

wt = 'chweight'

# Run for loop

for year in year_list:

    df = read_csv_file(country, recode, year, file_type='working')

    out_fn = country + "_" + recode + "_" + year + ".xlsx"
    path = Path.cwd() / 'output' / 'frequencies' / recode / out_fn
    
    # Instantiate object
    xlwriter = pd.ExcelWriter(path)
    
    for var in vars:

        try:
            # df = df.dropna(subset=[var])
            output = output_mean_table(df.dropna(subset=[var]), var, ind_vars, wt)
            sheet_name = str(var) + '_weighted'
            output.to_excel(xlwriter, sheet_name=sheet_name)
        
        except:
            print(f"Warning: Unable to create sheet for var {var}")

    xlwriter.close()
# Out:
# The file -- LAO_children_2000_working.csv -- has the following shape: Rows: 5152; Columns: 31
# Warning: Unable to create sheet for var mdd_ch
# Warning: Unable to create sheet for var mmf_ch
# Warning: Unable to create sheet for var mad_ch
# The file -- LAO_children_2006_working.csv -- has the following shape: Rows: 4136; Columns: 25
# Warning: Unable to create sheet for var mdd_ch
# Warning: Unable to create sheet for var mmf_ch
# Warning: Unable to create sheet for var mad_ch
# The file -- LAO_children_2012_working.csv -- has the following shape: Rows: 11067; Columns: 34
# Warning: Unable to create sheet for var mdd_ch
# Warning: Unable to create sheet for var mad_ch
# The file -- LAO_children_2017_working.csv -- has the following shape: Rows: 11720; Columns: 46

# %% [markdown]
# ### Run Bivariate stats

# %%
# Read in combined file
df = read_csv_file(country, recode, file_type='combined')

# Create updated bivariate variables (mother_edu_biv, eth_hoh_biv)
df = create_bivariate_var_dep(df, country)
# Out:
# The file -- LAO_children_combined.csv -- has the following shape: Rows: 32075; Columns: 52
# c:\Users\Lindsey\OneDrive - A3DI\Alive & Thrive\3_Country_II\tabulate_vars.py:38: DtypeWarning: Columns (24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
# Set parameters
recode = 'children'

var_dep_list = ['excl_bf', 'cont_1223_bf', 'mdd_ch', 'mmf_ch', 'mad_ch', 'stunting_ch', 'wasting_ch', 'overweight_ch']

ind_var_list = ['sex_ch', 'residence', 'region', 'mother_edu_biv', 'wealth_q', 'eth_hoh_biv', 'elderly_hoh', 'sex_hoh']

# Run bivariate (extract WLS regression params)
output = {var_dep: pd.DataFrame({ind_var: extract_regression_params(df, var_dep, ind_var, recode) for ind_var in ind_var_list}) for var_dep in var_dep_list}
# Out:
# sex_ch
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.047
# Model:                            WLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     28.30
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           7.38e-18
# Time:                        12:12:26   Log-Likelihood:                -9130.6
# No. Observations:                1714   AIC:                         1.827e+04
# Df Residuals:                    1710   BIC:                         1.829e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# intercept                22.9074      2.731      8.387      0.000      17.551      28.264
# int_2017_CH Sex: Male    -2.5561      4.833     -0.529      0.597     -12.036       6.924
# Year_2017                23.4227      3.382      6.926      0.000      16.790      30.056
# sex_ch_CH Sex: Male      -0.2229      3.934     -0.057      0.955      -7.939       7.493
# ==============================================================================
# Omnibus:                    14640.652   Durbin-Watson:                   1.599
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.128
# Skew:                           0.285   Prob(JB):                     6.92e-38
# Kurtosis:                       1.561   Cond. No.                         8.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.052
# Model:                            WLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     31.06
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.50e-19
# Time:                        12:12:26   Log-Likelihood:                -9126.6
# No. Observations:                1714   AIC:                         1.826e+04
# Df Residuals:                    1710   BIC:                         1.828e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          25.4638      2.184     11.659      0.000      21.180      29.748
# int_2017_Urban     10.2065      5.922      1.724      0.085      -1.408      21.821
# Year_2017          20.3557      2.718      7.488      0.000      15.024      25.687
# residence_Urban   -13.7560      4.963     -2.772      0.006     -23.491      -4.021
# ==============================================================================
# Omnibus:                    14497.146   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.471
# Skew:                           0.273   Prob(JB):                     1.58e-37
# Kurtosis:                       1.559   Cond. No.                         8.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.160
# Model:                            WLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     70.77
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           6.71e-42
# Time:                        12:12:26   Log-Likelihood:                -5892.5
# No. Observations:                1119   AIC:                         1.179e+04
# Df Residuals:                    1115   BIC:                         1.181e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# intercept          7.8704      3.069      2.565      0.010       1.849      13.891
# int_2017_North   -11.6180      5.627     -2.065      0.039     -22.659      -0.577
# Year_2017         35.6927      4.119      8.666      0.000      27.611      43.774
# region_North      30.9646      4.373      7.080      0.000      22.383      39.546
# ==============================================================================
# Omnibus:                     1466.400   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.966
# Skew:                           0.009   Prob(JB):                     8.68e-17
# Kurtosis:                       1.741   Cond. No.                         8.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.048
# Model:                            WLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     28.71
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           4.14e-18
# Time:                        12:12:26   Log-Likelihood:                -9130.0
# No. Observations:                1714   AIC:                         1.827e+04
# Df Residuals:                    1710   BIC:                         1.829e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          23.7388      2.135     11.121      0.000      19.552      27.925
# int_2017_Secondary_Higher           3.4847      6.160      0.566      0.572      -8.598      15.567
# Year_2017                          22.3220      2.824      7.905      0.000      16.784      27.860
# mother_edu_biv_Secondary_Higher    -6.1575      5.467     -1.126      0.260     -16.880       4.565
# ==============================================================================
# Omnibus:                    14834.245   Durbin-Watson:                   1.605
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.668
# Skew:                           0.286   Prob(JB):                     8.71e-38
# Kurtosis:                       1.563   Cond. No.                         9.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.097
# Model:                            WLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           7.57e-17
# Time:                        12:12:26   Log-Likelihood:                -4066.6
# No. Observations:                 768   AIC:                             8141.
# Df Residuals:                     764   BIC:                             8160.
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           10.9988      4.663      2.359      0.019       1.845      20.152
# int_2017_Poorest     6.8459      7.226      0.947      0.344      -7.339      21.031
# Year_2017           18.3284      5.725      3.201      0.001       7.089      29.567
# wealth_q_Poorest    17.1054      5.874      2.912      0.004       5.575      28.636
# ==============================================================================
# Omnibus:                      389.124   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.017
# Skew:                           0.315   Prob(JB):                     1.13e-12
# Kurtosis:                       1.850   Cond. No.                         9.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.097
# Model:                            WLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     61.34
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.15e-37
# Time:                        12:12:26   Log-Likelihood:                -9084.5
# No. Observations:                1714   AIC:                         1.818e+04
# Df Residuals:                    1710   BIC:                         1.820e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              34.2161      2.811     12.171      0.000      28.702      39.730
# int_2017_Lao_Tai       -0.7956      4.717     -0.169      0.866     -10.047       8.456
# Year_2017              22.6559      3.460      6.547      0.000      15.869      29.443
# eth_hoh_biv_Lao_Tai   -21.2724      3.838     -5.543      0.000     -28.799     -13.746
# ==============================================================================
# Omnibus:                     1275.701   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.077
# Skew:                           0.324   Prob(JB):                     3.44e-29
# Kurtosis:                       1.810   Cond. No.                         8.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.047
# Model:                            WLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     28.33
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           7.11e-18
# Time:                        12:12:26   Log-Likelihood:                -9130.5
# No. Observations:                1714   AIC:                         1.827e+04
# Df Residuals:                    1710   BIC:                         1.829e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      19.4611      5.908      3.294      0.001       7.874      31.049
# int_2017_Elderly HoH: NO       -6.8275      7.263     -0.940      0.347     -21.072       7.417
# Year_2017                      27.9947      6.783      4.127      0.000      14.691      41.298
# elderly_hoh_Elderly HoH: NO     3.7546      6.265      0.599      0.549      -8.533      16.042
# ==============================================================================
# Omnibus:                    14287.402   Durbin-Watson:                   1.600
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.743
# Skew:                           0.283   Prob(JB):                     5.09e-38
# Kurtosis:                       1.557   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                excl_bf   R-squared:                       0.053
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     32.13
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           3.35e-20
# Time:                        12:12:26   Log-Likelihood:                -9125.1
# No. Observations:                1714   AIC:                         1.826e+04
# Df Residuals:                    1710   BIC:                         1.828e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        13.6317      7.643      1.784      0.075      -1.358      28.622
# int_2017_Male     4.2571      9.032      0.471      0.637     -13.458      21.972
# Year_2017        18.8623      8.675      2.174      0.030       1.848      35.876
# sex_hoh_Male      9.8135      7.907      1.241      0.215      -5.695      25.322
# ==============================================================================
# Omnibus:                    19318.413   Durbin-Watson:                   1.617
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.147
# Skew:                           0.289   Prob(JB):                     2.27e-36
# Kurtosis:                       1.599   Cond. No.                         23.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_ch
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.045
# Model:                            WLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     49.47
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           3.03e-31
# Time:                        12:12:26   Log-Likelihood:                -17106.
# No. Observations:                3190   AIC:                         3.422e+04
# Df Residuals:                    3186   BIC:                         3.425e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# intercept                64.7325      2.200     29.424      0.000      60.419      69.046
# int_2017_CH Sex: Male    -1.6467      3.757     -0.438      0.661      -9.013       5.720
# Year_2017               -22.0349      2.673     -8.242      0.000     -27.277     -16.793
# sex_ch_CH Sex: Male       1.8507      3.126      0.592      0.554      -4.278       7.980
# ==============================================================================
# Omnibus:                    16566.927   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              336.477
# Skew:                          -0.020   Prob(JB):                     8.61e-74
# Kurtosis:                       1.409   Cond. No.                         8.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.082
# Model:                            WLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     95.43
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           3.84e-59
# Time:                        12:12:26   Log-Likelihood:                -17042.
# No. Observations:                3190   AIC:                         3.409e+04
# Df Residuals:                    3186   BIC:                         3.412e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          70.7929      1.766     40.096      0.000      67.331      74.255
# int_2017_Urban     -1.2750      4.192     -0.304      0.761      -9.494       6.944
# Year_2017         -21.4334      2.144     -9.999      0.000     -25.636     -17.230
# residence_Urban   -20.7832      3.549     -5.856      0.000     -27.742     -13.825
# ==============================================================================
# Omnibus:                    30049.462   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              265.037
# Skew:                          -0.031   Prob(JB):                     2.80e-58
# Kurtosis:                       1.589   Cond. No.                         8.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.050
# Model:                            WLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     41.00
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           8.05e-26
# Time:                        12:12:26   Log-Likelihood:                -12667.
# No. Observations:                2364   AIC:                         2.534e+04
# Df Residuals:                    2360   BIC:                         2.536e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           70.0000      2.787     25.120      0.000      64.536      75.464
# int_2017_Central     0.0407      4.524      0.009      0.993      -8.831       8.912
# Year_2017          -22.3432      3.339     -6.692      0.000     -28.891     -15.796
# region_Central      -8.9831      3.839     -2.340      0.019     -16.511      -1.455
# ==============================================================================
# Omnibus:                    13462.198   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              240.567
# Skew:                           0.096   Prob(JB):                     5.77e-53
# Kurtosis:                       1.449   Cond. No.                         9.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.080
# Model:                            WLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     92.38
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           2.51e-57
# Time:                        12:12:26   Log-Likelihood:                -17046.
# No. Observations:                3190   AIC:                         3.410e+04
# Df Residuals:                    3186   BIC:                         3.412e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          69.6786      1.727     40.343      0.000      66.292      73.065
# int_2017_Secondary_Higher          -1.3258      4.284     -0.310      0.757      -9.725       7.073
# Year_2017                         -18.1152      2.193     -8.260      0.000     -22.415     -13.815
# mother_edu_biv_Secondary_Higher   -19.0462      3.755     -5.072      0.000     -26.409     -11.684
# ==============================================================================
# Omnibus:                    31667.782   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              262.541
# Skew:                          -0.032   Prob(JB):                     9.77e-58
# Kurtosis:                       1.596   Cond. No.                         9.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.209
# Model:                            WLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     116.5
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           6.23e-67
# Time:                        12:12:26   Log-Likelihood:                -6966.5
# No. Observations:                1324   AIC:                         1.394e+04
# Df Residuals:                    1320   BIC:                         1.396e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           79.7280      2.931     27.201      0.000      73.978      85.478
# int_2017_Richest   -19.0843      5.359     -3.561      0.000     -29.597      -8.572
# Year_2017          -13.2377      3.499     -3.783      0.000     -20.102      -6.373
# wealth_q_Richest   -27.9990      4.455     -6.284      0.000     -36.739     -19.259
# ==============================================================================
# Omnibus:                       85.656   Durbin-Watson:                   1.823
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.640
# Skew:                          -0.210   Prob(JB):                     4.07e-09
# Kurtosis:                       2.276   Cond. No.                         8.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.113
# Model:                            WLS   Adj. R-squared:                  0.112
# Method:                 Least Squares   F-statistic:                     135.4
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.48e-82
# Time:                        12:12:27   Log-Likelihood:                -16988.
# No. Observations:                3190   AIC:                         3.398e+04
# Df Residuals:                    3186   BIC:                         3.401e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              79.4383      2.394     33.184      0.000      74.745      84.132
# int_2017_Lao_Tai       -5.1702      3.683     -1.404      0.161     -12.392       2.052
# Year_2017             -20.8275      2.835     -7.347      0.000     -26.386     -15.269
# eth_hoh_biv_Lao_Tai   -22.8178      3.079     -7.410      0.000     -28.856     -16.780
# ==============================================================================
# Omnibus:                     2976.563   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              199.501
# Skew:                           0.088   Prob(JB):                     4.77e-44
# Kurtosis:                       1.788   Cond. No.                         9.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.049
# Model:                            WLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     54.59
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           2.09e-34
# Time:                        12:12:27   Log-Likelihood:                -17099.
# No. Observations:                3190   AIC:                         3.421e+04
# Df Residuals:                    3186   BIC:                         3.423e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                      59.8481      4.120     14.525      0.000      51.769      67.927
# int_2017_Elderly HoH: NO        3.2158      5.258      0.612      0.541      -7.094      13.526
# Year_2017                     -25.3857      4.850     -5.234      0.000     -34.895     -15.876
# elderly_hoh_Elderly HoH: NO     6.7708      4.451      1.521      0.128      -1.957      15.499
# ==============================================================================
# Omnibus:                    17112.901   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              328.893
# Skew:                          -0.020   Prob(JB):                     3.82e-72
# Kurtosis:                       1.427   Cond. No.                         17.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:           cont_1223_bf   R-squared:                       0.049
# Model:                            WLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     54.85
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.45e-34
# Time:                        12:12:27   Log-Likelihood:                -17099.
# No. Observations:                3190   AIC:                         3.421e+04
# Df Residuals:                    3186   BIC:                         3.423e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept        50.4998      5.539      9.118      0.000      39.640      61.360
# int_2017_Male    -7.0135      6.704     -1.046      0.296     -20.158       6.131
# Year_2017       -16.1584      6.411     -2.520      0.012     -28.728      -3.589
# sex_hoh_Male     16.4531      5.772      2.850      0.004       5.136      27.771
# ==============================================================================
# Omnibus:                    17321.355   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              326.099
# Skew:                          -0.012   Prob(JB):                     1.54e-71
# Kurtosis:                       1.434   Cond. No.                         23.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_ch
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.000
# Model:                            WLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.648
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):              0.199
# Time:                        12:12:27   Log-Likelihood:                -18388.
# No. Observations:                3428   AIC:                         3.678e+04
# Df Residuals:                    3426   BIC:                         3.679e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# intercept                17.2903      0.597     28.953      0.000      16.119      18.461
# int_2017_CH Sex: Male     1.0526      0.820      1.284      0.199      -0.555       2.660
# Year_2017                17.2903      0.597     28.953      0.000      16.119      18.461
# sex_ch_CH Sex: Male       1.0526      0.820      1.284      0.199      -0.555       2.660
# ==============================================================================
# Omnibus:                     2032.623   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              481.454
# Skew:                           0.720   Prob(JB):                    2.84e-105
# Kurtosis:                       1.860   Cond. No.                     4.74e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.06e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.041
# Model:                            WLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     144.7
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.12e-32
# Time:                        12:12:27   Log-Likelihood:                -18318.
# No. Observations:                3428   AIC:                         3.664e+04
# Df Residuals:                    3426   BIC:                         3.665e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept          14.8028      0.474     31.219      0.000      13.873      15.732
# int_2017_Urban     10.6815      0.888     12.030      0.000       8.941      12.422
# Year_2017          14.8028      0.474     31.219      0.000      13.873      15.732
# residence_Urban    10.6815      0.888     12.030      0.000       8.941      12.422
# ==============================================================================
# Omnibus:                      836.273   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.782
# Skew:                           0.682   Prob(JB):                     6.92e-87
# Kurtosis:                       2.043   Cond. No.                     1.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.93e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.008
# Model:                            WLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     18.27
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           2.00e-05
# Time:                        12:12:27   Log-Likelihood:                -11802.
# No. Observations:                2188   AIC:                         2.361e+04
# Df Residuals:                    2186   BIC:                         2.362e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           15.1068      0.926     16.321      0.000      13.292      16.922
# int_2017_Central     4.7560      1.113      4.275      0.000       2.574       6.938
# Year_2017           15.1068      0.926     16.321      0.000      13.292      16.922
# region_Central       4.7560      1.113      4.275      0.000       2.574       6.938
# ==============================================================================
# Omnibus:                     1255.976   Durbin-Watson:                   1.694
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              272.604
# Skew:                           0.650   Prob(JB):                     6.38e-60
# Kurtosis:                       1.859   Cond. No.                     3.87e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.037
# Model:                            WLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     130.2
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.29e-29
# Time:                        12:12:27   Log-Likelihood:                -18325.
# No. Observations:                3428   AIC:                         3.665e+04
# Df Residuals:                    3426   BIC:                         3.667e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                          13.8290      0.534     25.881      0.000      12.781      14.877
# int_2017_Secondary_Higher           9.2449      0.810     11.409      0.000       7.656      10.834
# Year_2017                          13.8290      0.534     25.881      0.000      12.781      14.877
# mother_edu_biv_Secondary_Higher     9.2449      0.810     11.409      0.000       7.656      10.834
# ==============================================================================
# Omnibus:                     1017.886   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              402.682
# Skew:                           0.672   Prob(JB):                     3.62e-88
# Kurtosis:                       1.993   Cond. No.                     2.08e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.94e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.129
# Model:                            WLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     204.9
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           1.90e-43
# Time:                        12:12:27   Log-Likelihood:                -7378.6
# No. Observations:                1391   AIC:                         1.476e+04
# Df Residuals:                    1389   BIC:                         1.477e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept           11.6101      0.793     14.634      0.000      10.054      13.166
# int_2017_Richest    17.6502      1.233     14.313      0.000      15.231      20.069
# Year_2017           11.6101      0.793     14.634      0.000      10.054      13.166
# wealth_q_Richest    17.6502      1.233     14.313      0.000      15.231      20.069
# ==============================================================================
# Omnibus:                      130.575   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.954
# Skew:                           0.374   Prob(JB):                     2.89e-15
# Kurtosis:                       2.229   Cond. No.                     1.16e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.48e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.042
# Model:                            WLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     149.9
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           8.95e-34
# Time:                        12:12:27   Log-Likelihood:                -18316.
# No. Observations:                3428   AIC:                         3.664e+04
# Df Residuals:                    3426   BIC:                         3.665e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              12.2215      0.610     20.047      0.000      11.026      13.417
# int_2017_Lao_Tai        9.9035      0.809     12.245      0.000       8.318      11.489
# Year_2017              12.2215      0.610     20.047      0.000      11.026      13.417
# eth_hoh_biv_Lao_Tai     9.9035      0.809     12.245      0.000       8.318      11.489
# ==============================================================================
# Omnibus:                     2127.173   Durbin-Watson:                   1.736
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              366.633
# Skew:                           0.556   Prob(JB):                     2.44e-80
# Kurtosis:                       1.847   Cond. No.                     2.53e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.48e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 mdd_ch   R-squared:                       0.003
# Model:                            WLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     10.47
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):            0.00123
# Time:                        12:12:27   Log-Likelihood:                -18384.
# No. Observations:                3428   AIC:                         3.677e+04
# Df Residuals:                    3426   BIC:                         3.678e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
# ...
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# intercept                 2.7912      0.705      3.957      0.000       1.408       4.174
# int_2017_CH Sex: Male     1.0586      1.067      0.992      0.321      -1.033       3.150
# Year_2017                 0.3349      0.747      0.448      0.654      -1.129       1.799
# sex_ch_CH Sex: Male      -0.2767      1.011     -0.274      0.784      -2.258       1.704
# ==============================================================================
# Omnibus:                    13575.596   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           634099.591
# Skew:                           5.718   Prob(JB):                         0.00
# Kurtosis:                      35.715   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# residence
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.002
# Model:                            WLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     8.078
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           2.26e-05
# Time:                        12:12:32   Log-Likelihood:                -55636.
# No. Observations:               12671   AIC:                         1.113e+05
# Df Residuals:                   12667   BIC:                         1.113e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           2.5135      0.579      4.342      0.000       1.379       3.648
# int_2017_Urban      1.1859      1.244      0.953      0.340      -1.253       3.624
# Year_2017           0.5389      0.612      0.880      0.379      -0.661       1.739
# residence_Urban     0.5964      1.183      0.504      0.614      -1.722       2.914
# ==============================================================================
# Omnibus:                    13554.750   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           630118.577
# Skew:                           5.705   Prob(JB):                         0.00
# Kurtosis:                      35.608   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# region
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.002
# Model:                            WLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     5.215
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):            0.00135
# Time:                        12:12:32   Log-Likelihood:                -42045.
# No. Observations:                9517   AIC:                         8.410e+04
# Df Residuals:                    9513   BIC:                         8.413e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            4.7836      0.947      5.050      0.000       2.927       6.641
# int_2017_Central     2.2183      1.386      1.600      0.110      -0.499       4.936
# Year_2017           -0.3418      1.000     -0.342      0.732      -2.302       1.618
# region_Central      -3.3908      1.324     -2.561      0.010      -5.986      -0.796
# ==============================================================================
# Omnibus:                     9849.554   Durbin-Watson:                   1.827
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           394141.278
# Skew:                           5.449   Prob(JB):                         0.00
# Kurtosis:                      32.583   Cond. No.                         18.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# mother_edu_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.002
# Model:                            WLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     8.886
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           7.03e-06
# Time:                        12:12:32   Log-Likelihood:                -55635.
# No. Observations:               12671   AIC:                         1.113e+05
# Df Residuals:                   12667   BIC:                         1.113e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                       0.7976      1.199      0.665      0.506      -1.552       3.147
# int_2017_None_Primary          -3.8687      1.367     -2.829      0.005      -6.549      -1.189
# Year_2017                       3.7174      1.230      3.023      0.003       1.307       6.128
# mother_edu_biv_None_Primary     2.2595      1.322      1.710      0.087      -0.331       4.850
# ==============================================================================
# Omnibus:                    13548.019   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           628230.512
# Skew:                           5.701   Prob(JB):                         0.00
# Kurtosis:                      35.556   Cond. No.                         25.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# wealth_q
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.004
# Model:                            WLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     6.440
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           0.000238
# Time:                        12:12:32   Log-Likelihood:                -24230.
# No. Observations:                5338   AIC:                         4.847e+04
# Df Residuals:                    5334   BIC:                         4.849e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# intercept            4.1743      1.203      3.471      0.001       1.817       6.532
# int_2017_Richest     4.6185      1.879      2.458      0.014       0.935       8.302
# Year_2017           -0.1759      1.265     -0.139      0.889      -2.655       2.303
# wealth_q_Richest    -2.2528      1.770     -1.273      0.203      -5.723       1.217
# ==============================================================================
# Omnibus:                     5092.179   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144206.774
# Skew:                           4.882   Prob(JB):                         0.00
# Kurtosis:                      26.517   Cond. No.                         14.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# eth_hoh_biv
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.001
# Model:                            WLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.014
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):             0.0288
# Time:                        12:12:32   Log-Likelihood:                -55643.
# No. Observations:               12671   AIC:                         1.113e+05
# Df Residuals:                   12667   BIC:                         1.113e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept               4.3355      0.836      5.189      0.000       2.698       5.973
# int_2017_Lao_Tai        2.6806      1.104      2.428      0.015       0.517       4.845
# Year_2017              -0.8273      0.874     -0.946      0.344      -2.541       0.887
# eth_hoh_biv_Lao_Tai    -2.6460      1.049     -2.523      0.012      -4.702      -0.590
# ==============================================================================
# Omnibus:                    13580.077   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           635604.609
# Skew:                           5.720   Prob(JB):                         0.00
# Kurtosis:                      35.757   Cond. No.                         18.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# elderly_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.000
# Model:                            WLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.634
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):              0.179
# Time:                        12:12:32   Log-Likelihood:                -55646.
# No. Observations:               12671   AIC:                         1.113e+05
# Df Residuals:                   12667   BIC:                         1.113e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# intercept                       1.8121      1.474      1.229      0.219      -1.078       4.702
# int_2017_Elderly HoH: NO       -1.5827      1.635     -0.968      0.333      -4.788       1.622
# Year_2017                       2.2374      1.533      1.460      0.144      -0.767       5.242
# elderly_hoh_Elderly HoH: NO     0.9566      1.569      0.610      0.542      -2.120       4.033
# ==============================================================================
# Omnibus:                    13580.733   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           635357.549
# Skew:                           5.721   Prob(JB):                         0.00
# Kurtosis:                      35.749   Cond. No.                         33.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None
# sex_hoh
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:          overweight_ch   R-squared:                       0.002
# Model:                            WLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     6.988
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):           0.000108
# Time:                        12:12:33   Log-Likelihood:                -55637.
# No. Observations:               12671   AIC:                         1.113e+05
# Df Residuals:                   12667   BIC:                         1.113e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept         1.0365      1.925      0.538      0.590      -2.737       4.809
# int_2017_Male    -4.1105      2.073     -1.982      0.047      -8.175      -0.046
# Year_2017         4.6221      1.998      2.313      0.021       0.705       8.539
# sex_hoh_Male      1.7396      1.995      0.872      0.383      -2.170       5.650
# ==============================================================================
# Omnibus:                    13554.825   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           630176.038
# Skew:                           5.705   Prob(JB):                         0.00
# Kurtosis:                      35.610   Cond. No.                         44.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Summary of OLS:
#  None

# %%
# Generate csv of outputs
for var in var_dep_list:
    fn = var + '.csv'
    output[var].transpose().to_csv(f"./output/bivariate/{recode}/{fn}")

# %% [markdown]
# #### Get bivariate differences

# %%
df = read_csv_file(country, recode, file_type='combined')

df = create_bivariate_var_dep(df, country)

var_dep_list = ['excl_bf', 'cont_1223_bf', 'mdd_ch', 'mmf_ch', 'mad_ch', 'stunting_ch', 'wasting_ch', 'overweight_ch'] 

ind_var_list = ['sex_ch', 'residence', 'region', 'mother_edu_biv', 'wealth_q', 'eth_hoh_biv', 'elderly_hoh', 'sex_hoh']


for var in var_dep_list:

    out_fn = var + "_bivariate_diff" + ".xlsx"
    path = Path.cwd() / 'output' / 'bivariate' / recode / out_fn

    # Instantiate object
    xlwriter = pd.ExcelWriter(path)

    for ind_var in ind_var_list:

        output = df.groupby(['Year', ind_var]).apply(mean_wt, var, wt=wt).unstack().transpose()
        
        sheet_name = str(ind_var) + '_weighted'
        output.to_excel(xlwriter, sheet_name=sheet_name)

    xlwriter.close()
# Out:
# c:\Users\Lindsey\OneDrive - A3DI\Alive & Thrive\3_Country_II\tabulate_vars.py:38: DtypeWarning: Columns (24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# The file -- LAO_children_combined.csv -- has the following shape: Rows: 32075; Columns: 52

# %%
var = 'excl_bf'
ind_var = 'mother_edu_biv'
wt = 'chweight'

df.groupby(['Year', ind_var]).apply(mean_wt, var, wt=wt).unstack().transpose()
# Out:
# Year              2000  2006  2012  2017
# mother_edu_biv
# None_Primary      23.7  26.6  39.3  46.1
# Secondary_Higher  17.6  26.7  42.8  43.4
